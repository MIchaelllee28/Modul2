# %% [markdown]
# <a href="https://colab.research.google.com/github/MIchaelllee28/Modul2/blob/main/quiz_citra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive


# Accessing my google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#tampilan gambar asli
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/1/soal3.jpg')
plt.imshow(img)

# %%
#mengubah warna menjadi ungu gelap
img1 = cv.imread('/content/drive/MyDrive/1/soal3.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img1, cmap='RdPu')

# %%
#emngubah ukuran
img4 = cv.resize(img, (2000,2000))
plt.imshow(img4)

# %%
# TUGAS
# GARIS VERTIKAL dan HORIZONTAL

tinggi = img.shape[0]
lebar = img.shape[1]

image_1 = cv.cvtColor(img, cv.COLOR_BGR2RGB)

# membuat garis vertikal di tengah image
for x in range (tinggi):
  image_1[x, int((lebar)/2)] = [255,255,255]


# membuat garis horizontal di tengah image
for y in range (lebar):
  image_2[int((tinggi)/2),y] = [255,255,0]

final_frame = cv.hconcat((image_1, image_2))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=2000x1000 at 0x7FF6A58379A0>

# %%
#membuat gambar secara horzontal
hori = cv.flip(img, 1)
plt.imshow(hori)

# %%
#membuat gambar secara vertikal
hori = cv.flip(img, 0)
plt.imshow(hori)

# %%
# Buat kotak berbagai ukuran dan warna yang berbeda dalam satu image. 
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img3,pt1=(200,300),pt2=(400,100),color=(255,4,100),thickness=10)
cv.rectangle(img3,pt1=(500,200),pt2=(600,300),color=(100,255,200),thickness=10)
plt.imshow(img3)
