# %% [markdown]
# <a href="https://colab.research.google.com/github/MIchaelllee28/Modul2/blob/main/modul2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive


# Accessing my google drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/modul2/gambar1guguk.jfif')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/modul2/gambar2kucing.jfif', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(7,7))   #ubah sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik pt1 dan pt2 , pojok kiri atas dan pojok kanan bawah
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
#inisialisasi numpy array dengan type data int32
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
#reshape array
pts = vertices.reshape((-1,1,2)) #nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yang mewakili RGB
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
#penambahan polyline pada black image kedua
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# PERTANYAAN
#
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
#
#   maka gambar tersebut tidak akan memiliki plot grafik yang bisa ditampilkan setelah kode di run
#
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16 dan int32?
#
#   perbedaannya terletak pada kapasitas bit penyimpanan antara keduanya
#
# 3. Jelaskan tentang angka-angka yang terdapat pada reshape((-1,1,2))
#
#   angka tersebut merupakan 3 array yang mewakilkan warna merah, hijau, dan biru (RGB)
#
# 4. Apakah kegunaan "google.colab.patches import cv2_imshow"
#
#   kode tersebut digunakan untuk menampilkan gambar pada OpenCV di Google Colab.
#
# 5. Apakah kegunaan “skimage impot io” pada potongan kode soal nomor 4
#
#   kode tersebut berfungsi pada pemrosesan gambar.

# %%
#TUGAS
# NO 1
# Red Green
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img3[:,:,2] = 0
plt.imshow(img3)

# %%
# Green Blue
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img3[:,:,0] = 0
plt.imshow(img3)

# %%
# NO 2
#  image baris ke 10-100, kolom 10-100
plt.imshow(img[10:100, 10:100])

# %%
# NO 3
#  image baris ke 5-30, semua kolom, channel Green saja
# Green Blue
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img3[:,:,(0,2)] = 0
plt.imshow(img3[5:30])

# %%
# NO 4
# Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image. 
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img3,pt1=(200,300),pt2=(400,100),color=(255,0,0),thickness=10)
cv.rectangle(img3,pt1=(500,200),pt2=(600,300),color=(0,255,0),thickness=10)
cv.rectangle(img3,pt1=(100,400),pt2=(300,600),color=(0,0,255),thickness=10)
cv.rectangle(img3,pt1=(200,100),pt2=(150,50),color=(0,255,255),thickness=10)
cv.rectangle(img3,pt1=(600,450),pt2=(500,350),color=(255,255,255),thickness=10)
plt.imshow(img3)

# %%
# NO 5
# Tampilkan image dengan posisi terbalik!
img = cv.imread('/content/drive/MyDrive/modul2/27 Cat Pictures Taken at Exactly the Right Moment _ Cuteness.jfif')
img_flip = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB), 0)
plt.imshow(img_flip)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img3[:,:,0] = 0
plt.imshow(img3)

# %%
# NO 2
#  image baris ke 10-100, kolom 10-100
plt.imshow(img[10:100, 10:100])

# %%
# NO 3
#  image baris ke 5-30, semua kolom, channel Green saja
# Green Blue
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img3[:,:,(0,2)] = 0
plt.imshow(img3[5:30])

# %%
# NO 4
# Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image. 
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img3,pt1=(200,300),pt2=(400,100),color=(255,0,0),thickness=10)
cv.rectangle(img3,pt1=(500,200),pt2=(600,300),color=(0,255,0),thickness=10)
cv.rectangle(img3,pt1=(100,400),pt2=(300,600),color=(0,0,255),thickness=10)
cv.rectangle(img3,pt1=(200,100),pt2=(150,50),color=(0,255,255),thickness=10)
cv.rectangle(img3,pt1=(600,450),pt2=(500,350),color=(255,255,255),thickness=10)
plt.imshow(img3)

# %%
# NO 5
# Tampilkan image dengan posisi terbalik!
img = cv.imread('/content/drive/MyDrive/modul2/gambar2kucing.jfif')
img_flip = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB), 0)
plt.imshow(img_flip)

# %%
# NO 6
# Buat rectangle dan circle pada bagian wajah dari image kitten!
img = cv.imread('/content/drive/MyDrive/modul2/gambar2kucing.jfif')
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.circle(img3, (390,150), 110, (255,0,0), 5)
cv.rectangle(img3,pt1=(300,50),pt2=(500,250),color=(0,255,0),thickness=10)
plt.imshow(img3)

# %%
# NO 7
# Buat rectangle pada sudut bawah kiri channel B pada color space RGB dari citra kitten01.jpg!
img = cv.imread('/content/drive/MyDrive/modul2/gambar2kucing.jfif')
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img3[:,:,(0,1)] = 0
cv.rectangle(img3,pt1=(100,600),pt2=(10,500),color=(0,255,0),thickness=10)
plt.imshow(img3)
